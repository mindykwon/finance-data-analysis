# %%
import requests

input_data = {"pGB":1, "gicode":"A005950"}
result = requests.get("http://comp.fnguide.com/SVO2/ASP/SVD_Finance.asp", data = input_data)
print(result.text)
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
#
# <link rel="stylesheet" href="../css/compeach.css?ver3">
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <meta charset="utf-8">
# <meta content="width=device-width" name="viewport">
# <!-- <meta content="width=device-width,initial-scale=1.0,minimum-scale=1.0,maximum-scale=1.0" name="viewport"> -->
# <script type="text/javascript" src="../js/lib/jquery-1.11.1.min.js"></script>
# <script type="text/javascript" src="../js/comp_load.js?ver=1.1"></script>
# <script type="text/javascript" src="../js/lib/jquery.autocomplete.js"></script>
# <link rel="stylesheet" type="text/css" href="../css/jquery.autocomplete.css" />
# <LINK REL="SHORTCUT ICON" HREF="/SVO2/img/CompanyGuide.ico">
# <script type="text/javascript" src="../js/autocomplete.js"></script>
#
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async src="https://www.googletagmanager.com/gtag/js?id=UA-74989022-16"></script>
# <script>
# ...
